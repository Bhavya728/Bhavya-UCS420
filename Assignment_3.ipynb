# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavya728/Bhavya-UCS420/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Create a dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ea1e957-e33c-484c-bb99-0070d1d23aab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ea1e957-e33c-484c-bb99-0070d1d23aab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Upload widget is only available when the cell has been executed in the current browser session. Please rerun this cell to enable.
# Saving dataset - Sheet1.csv to dataset - Sheet1.csv

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['dataset - Sheet1.csv']))
print(df)
# Out:
#    Tid Refund Marital Status Taxable Income Cheat
# 0    1    Yes         Single           125K    no
# 1    2     No        Married           100K    no
# 2    3     No         Single            70K    no
# 3    4    Yes        Married           120K    no
# 4    5     No       Divorced            95K   yes
# 5    6     No       Married             60K    no
# 6    7    Yes       Divorced           220K    no
# 7    8     No         Single            85K   yes
# 8    9     No        Married            75K    no
# 9   10     No         Single            90K   yes

# %% [markdown]
# Q2. From the above table that you have created, locate row 0, 4, 7 and 8 using DataFrame.

# %%
print(df.loc[0],"\n")
print(df.loc[4],"\n")
print(df.loc[7],"\n")
print(df.loc[8],"\n")
# Out:
# Tid                    1
# Refund               Yes
# Marital Status    Single
# Taxable Income      125K
# Cheat                 no
# Name: 0, dtype: object
#
# Tid                      5
# Refund                  No
# Marital Status    Divorced
# Taxable Income         95K
# Cheat                  yes
# Name: 4, dtype: object
#
# Tid                    8
# Refund                No
# Marital Status    Single
# Taxable Income       85K
# Cheat                yes
# Name: 7, dtype: object
#
# Tid                     9
# Refund                 No
# Marital Status    Married
# Taxable Income        75K
# Cheat                  no
# Name: 8, dtype: object

# %% [markdown]
# Q3. Navigate the DataFrame and do the following task for the table created in question 1:
#
# Select row from index 3 to 7.
# Select row from index 4 to 8, and column 2 to 4.
# Select all rows with column index 1 to 3 (include index 3 during selection)

# %%
df.iloc[3:8]
# Out:
#    Tid Refund Marital Status Taxable Income Cheat
# 3    4    Yes        Married           120K    no
# 4    5     No       Divorced            95K   yes
# 5    6     No       Married             60K    no
# 6    7    Yes       Divorced           220K    no
# 7    8     No         Single            85K   yes

# %%
df.iloc[4:9, 2:5]
# Out:
#   Marital Status Taxable Income Cheat
# 4       Divorced            95K   yes
# 5       Married             60K    no
# 6       Divorced           220K    no
# 7         Single            85K   yes
# 8        Married            75K    no

# %%
df.iloc[:, 1:4]
# Out:
#   Refund Marital Status Taxable Income
# 0    Yes         Single           125K
# 1     No        Married           100K
# 2     No         Single            70K
# 3    Yes        Married           120K
# 4     No       Divorced            95K
# 5     No       Married             60K
# 6    Yes       Divorced           220K
# 7     No         Single            85K
# 8     No        Married            75K
# 9     No         Single            90K

# %% [markdown]
# Q4. Read a csv file and display its first five rows.

# %% [markdown]
# Upload widget is only available when the cell has been executed in the current browser session. Please rerun this cell to enable.
# Saving Iris.csv to Iris.csv

# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd
import io
df=pd.read_csv(io.BytesIO(uploaded['Iris.csv']))
print(df.head())

# %% [markdown]
# Q5. From the csv file (uploaded in the Q.4) delete row 4, and delete column 3. Display the result

# %%
import pandas as pd
import io
df=pd.read_csv(io.BytesIO(uploaded['Iris.csv']))
print(df.head())

# %% [markdown]
# Q5. From the csv file (uploaded in the Q.4) delete row 4, and delete column 3. Display the result

# %%
df.drop(3,axis=0)
df.drop(df.columns[2],axis=1)

# %% [markdown]
# Q6. Create a sample dataset (employees.csv) containing information about employees in a company

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io
df=pd.read_csv(io.BytesIO(uploaded['employees - Sheet1.csv']))
print(df)
# Out:
#      <input type="file" id="files-cdcd2176-779d-4a74-9761-f29da30f5435" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdcd2176-779d-4a74-9761-f29da30f5435">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# a) Shape (number of rows and columns) of the DataFrame

# %%
shape = df.shape
print(shape)
# Out:
# (5, 10)

# %% [markdown]
# b) Summary of the DataFrame that includes the data types and non-null counts for each column

# %%
summary = df.info()
print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          5 non-null      int64
#  1   Name                 5 non-null      object
#  2   Department           5 non-null      object
#  3   Age                  5 non-null      int64
#  4   Salary               5 non-null      int64
#  5   Years_of_Experience  5 non-null      int64
#  6   Joining_Date         5 non-null      object
#  7   Gender               5 non-null      object
#  8   Bonus                5 non-null      int64
#  9   Rating               5 non-null      float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 532.0+ bytes
# None
